# %% [markdown]
# ## 질문 1
# 다음 중 상속에 관한 내용으로 옳은거 4개를 골라보세요.
#
#
# > 1 상속을 이용하면 코드를 효율적으로 재활용 할 수 있다.
#
# > 2 어떤 자식 클래스는 또 다른 클래스의 부모 클래스가 될 수 없다.
#
# > 3 자식 클래스는 부모 클래스의 모든 기능을 물려 받는다.
#
# > 4. 자식 클래스는 상속받은 기능을 바꿔서 사용할 수 있다.
#
# > 5. 자식 클래스의 인스턴스는 부모 클래스의 인스턴스이기도 하다.
#
# 나의 Pick 1,3,4,5

# %% [markdown]
# # 질문 2
# 다음 중 파이썬에서의 상속에 관한 내용으로 틀린 것을 고르시오.
#
# > 1 자식 클래스의 __init__ 메소드에서는 부모 클래스의 __init__ 메소드를 무조건 호출해야만 한다.
#
# > 2 super 함수를 사용하면 부모 클래스의 내용에 접근 할 수 있다.
#
# > 3 코드 내에서 부모 클래스 이름을 사용하면 부모 클래스의 내용에 접근 할 수 있습니다.
#
# > 4 자식 클래스가 부모 클래스를 상속받는 문법은 다음과 같습니다.
#     class 자식클래스(부모클래스):
#
# > 5 부모클래스에 정의된 메소드를 오버라이딩하고 싶으면 자식 클래스에서 똑같은 이름의 메소드로 재정의하면 된다.
#
# 나의 Pick! : 1번
# 해답: 1번

# %% [markdown]
# # 질문 3
# 다음 중 다중 상속에 관한 내용으로 틀린 것을 고르시오.
#
# > 1 일반 클래스들을 다중 상속받는 건 굉장히 흔한 경우이며 필요할 때마다 사용하면 된다.
#
# > 2 파이썬에서 다중 상속을 하게되면 해당 클래스의 mro는 상속을 받은 순서대로 설정된다.
#
# > 3 파이썬에서 다중 상속을 받아도 부모 클래스 간 중복되는 메서드를 자식 클래스에서 모두 오버라이딩하면 애매모호한 행동을 예방할 수 있기는 하다.
#
# > 4 몇몇 객체 지향 언어들은 다중 상속을 허용하지 않는다.
#
# 나이 Pick! : 2번
# 정답 : 1번
#
# 해설 : 부모 클래스를 참조할 때의 애매모호함 때문에 되도록 다중 상속을 하지 않는 것이 바람직합니다.
