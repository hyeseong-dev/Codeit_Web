# %%
import pandas as pd

iphone_df = pd.read_csv('data/iphone.csv',index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# 컬럼 리스트 2개 이상을 보고 싶을때! 
iphone_df[['디스플레이','Face ID', '출시 버전']] = 'x'
iphone_df # 3개의 컬럼들 전부에 값들이 모두 바뀐걸 볼 수 있음.
# Out:
#                       출시일 디스플레이  메모리 출시 버전 Face ID
# iPhone 7 Plus  2016-09-16     x  3GB     x       x
# iPhone 8       2017-09-22     x  2GB     x       x
# iPhone 8 Plus  2017-09-22     x  3GB     x       x
# iPhone X       2017-11-03     x  3GB     x       x
# iPhone XS      2018-09-21     x  4GB     x       x
# iPhone XS Max  2018-09-21     x  4GB     x       x

# %%
iphone_df.loc[['iPhone 7 Plus','iPhone 8']] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리 출시 버전 Face ID
# iPhone 7 Plus           o     o    o     o       o
# iPhone 8                o     o    o     o       o
# iPhone 8 Plus  2017-09-22     x  3GB     x       x
# iPhone X       2017-11-03     x  3GB     x       x
# iPhone XS      2018-09-21     x  4GB     x       x
# iPhone XS Max  2018-09-21     x  4GB     x       x

# %%
# 연속된 row들을 바꾸고 싶을 경우 slicing을 이용할 수 있음. 
# .loc 부분만 없애도 됨.
iphone_df.loc['iPhone 7 Plus':'iPhone X'] = 'ok'
iphone_df
# Out:
#                       출시일 디스플레이  메모리 출시 버전 Face ID
# iPhone 7 Plus          ok    ok   ok    ok      ok
# iPhone 8               ok    ok   ok    ok      ok
# iPhone 8 Plus          ok    ok   ok    ok      ok
# iPhone X               ok    ok   ok    ok      ok
# iPhone XS      2018-09-21     x  4GB     x       x
# iPhone XS Max  2018-09-21     x  4GB     x       x

# %%
iphone_df = pd.read_csv('data/iphone.csv',index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# # 조건으로 selecting 해봅시다.

# %%
iphone_df.dtypes
# Out:
# 출시일         object
# 디스플레이      float64
# 메모리         object
# 출시 버전       object
# Face ID     object
# dtype: object

# %%
iphone_df['디스플레이'] > 5
# Out:
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
iphone_df[iphone_df['디스플레이'] > 5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# re를 사용해서 2019-02-11과 같이 중간에 -를 빼고 값을 저장하는 방법
import re 
date_of_rel = iphone_df['출시일']
p = re.compile(r'[GB]')
series = iphone_df['메모리']
iphone_df['메모리'] = [int(p.sub("", i)) for i in series]
print(iphone_df)

# %%
iphone_df.dtypes
# Out:
# 출시일         object
# 디스플레이      float64
# 메모리          int64
# 출시 버전       object
# Face ID     object
# dtype: object

# %%
date_of_rel[:].replace("-", "") 

iphone_df['출시일'] = date_of_rel # date_of_rel은 Series 데이터 타입. 
iphone_df.as()
# Out:
#                     출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  20160916    5.5  3GB  iOS 10.0      No
# iPhone 8       20170922    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  20170922    5.5  3GB  iOS 11.0      No
# iPhone X       20171103    5.8  3GB  iOS 11.1     Yes
# iPhone XS      20180921    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  20180921    6.5  4GB  iOS 12.0     Yes

# %%
# 특정 칼럼의 데이터 타입을 바꾸는 방법!
iphone_df.astype({'출시일':'int'})
iphone_df
# Out:
#                     출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  20160916    5.5  3GB  iOS 10.0      No
# iPhone 8       20170922    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  20170922    5.5  3GB  iOS 11.0      No
# iPhone X       20171103    5.8  3GB  iOS 11.1     Yes
# iPhone XS      20180921    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  20180921    6.5  4GB  iOS 12.0     Yes

# %%
iphone
